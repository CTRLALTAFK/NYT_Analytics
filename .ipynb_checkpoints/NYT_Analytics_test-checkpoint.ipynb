# %%
# Dependencies
import csv
import matplotlib.pyplot as plt
import requests
import pandas as pd
import json
url = "https://api.nytimes.com/svc/search/v2/articlesearch.json?q=election&api-key=pnK1Mz23UG2CNjyghZcMyNDCwAvB4jgX"

# %%
#character_id = '4'
#url = base_url + character_id
print(url)
# Out:
# https://api.nytimes.com/svc/search/v2/articlesearch.json?q=election&api-key=pnK1Mz23UG2CNjyghZcMyNDCwAvB4jgX

# %%
response = requests.get(url)
print(response.url)
# Out:
# https://api.nytimes.com/svc/search/v2/articlesearch.json?q=election&api-key=pnK1Mz23UG2CNjyghZcMyNDCwAvB4jgX

# %%
data = response.json()
print(json.dumps(data, indent=4, sort_keys=True))
# Out:
# {
#     "copyright": "Copyright (c) 2019 The New York Times Company. All Rights Reserved.",
#     "response": {
#         "docs": [
#             {
#                 "_id": "nyt://article/ea939ead-69a5-572c-9d05-6dddad127dc7",
#                 "abstract": "With three of six seats vacant \u2014 and the 2020 elections looming \u2014 the Federal Election Commission cannot do its job.",
#                 "byline": {
#                     "organization": "The Editorial Board",
#                     "original": "By The Editorial Board",
#                     "person": []
#                 },
#                 "document_type": "article",
#                 "headline": {
#                     "content_kicker": null,
#                     "kicker": null,
#                     "main": "The Election Watchdog That Can\u2019t Bark",
#                     "name": null,
#                     "print_headline": "The Election Watchdog Without Any Bite",
#                     "seo": null,
# ...

# %%
print(f"Document headline is <{data['response']['docs'][0]['headline']['main']}.>")
# Out:
# Document headline is <The Election Watchdog That Can’t Bark.>
