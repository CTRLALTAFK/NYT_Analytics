# %%
# %matplotlib notebook

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import json
from pprint import pprint

# Import API key
from config import api_key

base_url = "https://api.nytimes.com/svc/search/v2/articlesearch.json?api-key="

# %%
#queries
queryTerm = "Chocolate"
startYear = "2016"
StartMonthDay = "0101"
endYear = "2016"
EndMonthDay = '0102'
articleCount = []

# %%
#Calling APIs
query_url = base_url + api_key + "&q=" + queryTerm + "&begin_date=" + startYear + StartMonthDay + "&begin_date=" + endYear + EndMonthDay
articles = requests.get(query_url).json()
for x in articles:
    articleCount.append(len(articles['response']['docs'])
print(articleCount)
# Out:
# {'_id': 'nyt://article/0b64b77b-4ced-545b-8b4f-46a49080de9e',
#  'abstract': 'Cranberry, maple and apple cider flavors the new bonbons from '
#              'Bixby & Co. in Rockland, Me.',
#  'byline': {'organization': None,
#             'original': 'By Florence Fabricant',
#             'person': [{'firstname': 'Florence',
#                         'lastname': 'Fabricant',
#                         'middlename': None,
#                         'organization': '',
#                         'qualifier': None,
#                         'rank': 1,
#                         'role': 'reported',
#                         'title': None}]},
#  'document_type': 'article',
#  'headline': {'content_kicker': None,
#               'kicker': 'Front Burner',
#               'main': 'Autumn Chocolates From Maine',
#               'name': None,
#               'print_headline': 'To Nibble: Chocolate Company Unveils Its Fall '
#                                 'Line',
#               'seo': None,
# ...
