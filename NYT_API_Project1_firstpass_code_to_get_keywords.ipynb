# %%
# Dependencies
import json
import requests
from pprint import pprint
from config import api_key
import pandas as pd
import numpy as np


# baseurl1 = emailed = https://api.nytimes.com/svc/mostpopular/v2/emailed/7.json?api-key=yourkey
# baseurl2 = facebook share = https://api.nytimes.com/svc/mostpopular/v2/shared/1/facebook.json?api-key=yourkey
# baseurl3 = viewed = https://api.nytimes.com/svc/mostpopular/v2/viewed/1.json?api-key=yourkey
# baseurl4 = article search = "https://api.nytimes.com/svc/search/v2/articlesearch.json?"


baseurl1 = "https://api.nytimes.com/svc/mostpopular/v2/emailed/7.json?"
baseurl2 = "https://api.nytimes.com/svc/mostpopular/v2/shared/1/facebook.json?"
baseurl3 = "https://api.nytimes.com/svc/mostpopular/v2/viewed/1.json?"
# baseurl4 = "https://api.nytimes.com/svc/search/v2/articlesearch.json?begin_date=20190101&end_date=20191003&facet_fields=news_desk&facet_filter=true&fl=Politics&sort=newest&"
baseurl4 = "https://api.nytimes.com/svc/search/v2/articlesearch.json?api-key=5GtLqmgGl9W1hvUjnbdmbMFDftGESnsN"

# %%
# Search for articles that mention politics
# query = "politics"

# %%
# Build query URL
new_url1 = baseurl1 + "api-key=" + api_key
new_url2 = baseurl2 + "api-key=" + api_key
new_url3 = baseurl3 + "api-key=" + api_key
# new_url4 = baseurl4 + "api-key=" + api_key
new_url4 = baseurl4

print(new_url1)
print(new_url2)
print(new_url3)
print(new_url4)
# Out:
# https://api.nytimes.com/svc/mostpopular/v2/emailed/7.json?api-key=5GtLqmgGl9W1hvUjnbdmbMFDftGESnsN
# https://api.nytimes.com/svc/mostpopular/v2/shared/1/facebook.json?api-key=5GtLqmgGl9W1hvUjnbdmbMFDftGESnsN
# https://api.nytimes.com/svc/mostpopular/v2/viewed/1.json?api-key=5GtLqmgGl9W1hvUjnbdmbMFDftGESnsN
# https://api.nytimes.com/svc/search/v2/articlesearch.json?api-key=5GtLqmgGl9W1hvUjnbdmbMFDftGESnsN

# %%
print(requests.get(new_url1))
print(requests.get(new_url2))
print(requests.get(new_url3))
print(requests.get(new_url4))
# Out:
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>

# %%
# # baseurl1 = emailed = https://api.nytimes.com/svc/mostpopular/v2/emailed/7.json?api-key=yourkey
# # Retrieving data and converting it into JSON
# pprint(requests.get(new_url1).json())

# # or use the following to print
# # Pretty Print the output of the JSON
# '''response = requests.get(new_url).json()
# print(json.dumps(response, indent=4, sort_keys=True))'''

# %%
# # baseurl2 = facebook share = https://api.nytimes.com/svc/mostpopular/v2/shared/1/facebook.json?api-key=yourkey
# pprint(requests.get(new_url2).json())

# %%
# # baseurl3 = viewed = https://api.nytimes.com/svc/mostpopular/v2/viewed/1.json?api-key=yourkey
# pprint(requests.get(new_url3).json())

# %%
# baseurl4 = article search = "https://api.nytimes.com/svc/search/v2/articlesearch.json?"
# Retrieving data and converting it into JSON
pprint(requests.get(new_url4).json())
# Out:
# {'copyright': 'Copyright (c) 2019 The New York Times Company. All Rights '
#               'Reserved.',
#  'response': {'docs': [{'_id': 'nyt://interactive/19c1579f-cf65-512e-9402-d34dacf62ddb',
#                         'abstract': 'Mayoral inaugurations often reflect '
#                                     'characteristics of both the mayor and the '
#                                     'era. Here are some reports and recordings '
#                                     'from inaugurations dating back to '
#                                     'Fiorello H. La Guardia in 1934.',
#                         'byline': {'organization': None,
#                                    'original': None,
#                                    'person': []},
#                         'document_type': 'multimedia',
#                         'headline': {'content_kicker': None,
#                                      'kicker': None,
# ...

# %%
articles = requests.get(new_url4).json()
# print(json.dumps(response, indent=4, sort_keys=True))
print(type(articles))
# Out:
# <class 'dict'>

# %%
# articles_list = [article for article in articles["response"]["docs"]]

# pprint(articles_list)
kw_list = []
for each in articles: 
    keyword_list=[articles][0]["response"]["docs"][0]['keywords'][0]['value']
    kw_list.append(keyword_list)
kw_list
    # keyword_list
#     pprint(keyword_list)
# Out:
# ['Inaugurations', 'Inaugurations', 'Inaugurations']

# %%
keywords_data = []

for x in range(1):
    response = requests.get(f"{new_url4}&page={x}").json()
pprint(response)
# Out:
# {'copyright': 'Copyright (c) 2019 The New York Times Company. All Rights '
#               'Reserved.',
#  'response': {'docs': [{'_id': 'nyt://interactive/19c1579f-cf65-512e-9402-d34dacf62ddb',
#                         'abstract': 'Mayoral inaugurations often reflect '
#                                     'characteristics of both the mayor and the '
#                                     'era. Here are some reports and recordings '
#                                     'from inaugurations dating back to '
#                                     'Fiorello H. La Guardia in 1934.',
#                         'byline': {'organization': None,
#                                    'original': None,
#                                    'person': []},
#                         'document_type': 'multimedia',
#                         'headline': {'content_kicker': None,
#                                      'kicker': None,
# ...

# %%
import pandas as pd
# art0 = response["response"]["docs"][5]["keywords"][0]["value"]
art1 = response["response"]["docs"][5]["keywords"]
art2 = art1[0]["value"]

pprint(art1)
print()
pprint(art2)
print()

print(type(art1))
print(type(art2))


KeyWords = []
for key in art1:
    KeyWords.append(key)
    print(type(key))
    print(key)
# Out:
# [{'major': 'N',
#   'name': 'subject',
#   'rank': 1,
#   'value': 'Murders and Attempted Murders'},
#  {'major': 'N',
#   'name': 'glocations',
#   'rank': 2,
#   'value': 'Williamsbridge (Bronx, NY)'},
#  {'major': 'N',
#   'name': 'organizations',
#   'rank': 3,
#   'value': 'Education Department (NYC)'},
#  {'major': 'N',
#   'name': 'organizations',
#   'rank': 4,
#   'value': 'Richard R Green Educational Campus (Bronx, NY)'},
#  {'major': 'N', 'name': 'subject', 'rank': 5, 'value': 'Assaults'}]
#
# 'Murders and Attempted Murders'
#
# <class 'list'>
# <class 'str'>
# <class 'dict'>
# {'name': 'subject', 'value': 'Murders and Attempted Murders', 'rank': 1, 'major': 'N'}
# <class 'dict'>
# {'name': 'glocations', 'value': 'Williamsbridge (Bronx, NY)', 'rank': 2, 'major': 'N'}
# <class 'dict'>
# {'name': 'organizations', 'value': 'Education Department (NYC)', 'rank': 3, 'major': 'N'}
# <class 'dict'>
# ...

# %%
print(type(key))
pprint(key)
print()
keytest = key["value"]
print(type(keytest))
keytest
# Out:
# <class 'dict'>
# {'major': 'N', 'name': 'subject', 'rank': 5, 'value': 'Assaults'}
#
# <class 'str'>
# 'Assaults'

# %%
def get_values():
    for x in range(5):
        response = requests.get(f"{new_url4}&page={x}").json()
        art1 = response["response"]["docs"][5]["keywords"]
        for key in art1:
            keytest = key["value"]
            Saved_Keywords.append(keytest)

# %%
response
# Out:
# {'status': 'OK',
#  'copyright': 'Copyright (c) 2019 The New York Times Company. All Rights Reserved.',
#  'response': {'docs': [{'web_url': 'https://www.nytimes.com/interactive/2013/12/30/nyregion/nyc-mayor-inaugurations.html',
#     'snippet': 'Mayoral inaugurations often reflect characteristics of both the mayor and the era. Here are some reports and recordings from inaugurations dating back to Fiorello H. La Guardia in 1934.',
#     'lead_paragraph': 'Mayoral inaugurations often reflect characteristics of both the mayor and the era. Here are some reports and recordings from inaugurations dating back to Fiorello H. La Guardia in 1934.',
#     'abstract': 'Mayoral inaugurations often reflect characteristics of both the mayor and the era. Here are some reports and recordings from inaugurations dating back to Fiorello H. La Guardia in 1934.',
#     'source': 'The New York Times',
#     'multimedia': [{'rank': 0,
#       'subtype': 'wide',
#       'caption': None,
# ...

# %%
Saved_Keywords = []
get_values()

# %%
Saved_Keywords
# Out:
# ['Murders and Attempted Murders',
#  'Williamsbridge (Bronx, NY)',
#  'Education Department (NYC)',
#  'Richard R Green Educational Campus (Bronx, NY)',
#  'Assaults',
#  'Iraq',
#  'Shear, Michael D',
#  'Sussman, Dalia',
#  'Islamic State in Iraq and Syria (ISIS)',
#  'Obama, Barack',
#  'United States Defense and Military Forces',
#  'United States International Relations',
#  'Polls and Public Opinion',
#  'United States',
#  'United States Politics and Government',
#  'Gardens and Gardening',
#  'Tortorello, Michael',
#  'Flowers and Plants',
#  'Des Moines (Iowa)',
#  'Greater Des Moines Botanical Garden',
#  'Bullies',
#  'Mueller, Benjamin',
#  'Estevez, Noel',
#  'Crump, Timothy',
#  'Murders and Attempted Murders',
#  'Self-Defense',
#  'Intermediate School 117 (Bronx, NY)',
#  'Education (K-12)',
#  'Mental Health and Disorders',
#  'Bronx (NYC)',
#  'Crouse, Karen',
#  'Golf',
#  'Woods, Tiger']

# %%
with open ("NewSavedKeywords.json", "w") as file:
    json.dump(Saved_Keywords,file)

# %%
# Put results into a DataFrame
art_df = pd.DataFrame()
art_df["Keywords"]=Saved_Keywords

print("art_df")
print(type(art_df))
art_df.describe()
# Out:
# art_df
# <class 'pandas.core.frame.DataFrame'>
#                              Keywords
# count                              33
# unique                             32
# top     Murders and Attempted Murders
# freq                                2
