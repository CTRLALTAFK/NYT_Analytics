# %%
import pandas as pd
from pprint import pprint
import os, codecs, json, csv, re, glob

# %%
print(os.getcwd())
# Out:
# C:\Users\Owner\Desktop\UNC BootCamp - HomeWork\0_Project1 - Team 5 NYT\TESTWebHose\Webhose_data

# %%
# 100 sample post from 1,124,495 matching query over past 30 days

# path_to_json = '/'
json_files = [pos_json for pos_json in os.listdir('C:/Users/Owner/newjsonfiles/') if pos_json.endswith('.json')]
print(type(json_files))
print(json_files)
# Out:
# <class 'list'>
# ...

# %%
filenames = []

for file in os.listdir('C:/Users/Owner/newjsonfiles/'):
    if file.endswith(".json"):
        filenames.append(os.path.join('C:/Users/Owner/newjsonfiles/', file))

for file in filenames:
    with codecs.open(file,'r','utf-8') as f: 
        combinedfiles = json.load(f,encoding='utf-8')
#         print(type(combinedfiles))
        pprint(combinedfiles)
#         combinedfiles_df = pd.DataFrame(combinedfiles)
#         pprint(f)  # shows 100 objects like this <codecs.StreamReaderWriter object at 0x0000016ED09C8F60>
# Out:
# {'author': 'Mary Clare Jalonick, The Associated Press',
#  'crawled': '2019-09-26T08:04:36.000+03:00',
#  'entities': {'locations': [{'name': 'washington', 'sentiment': 'none'},
#                             {'name': 'ukraine', 'sentiment': 'none'},
#                             {'name': 'utah', 'sentiment': 'none'}],
#               'organizations': [{'name': 'congress', 'sentiment': 'none'},
#                                 {'name': 'senate', 'sentiment': 'none'},
#                                 {'name': 'gop', 'sentiment': 'none'},
#                                 {'name': 'house', 'sentiment': 'none'},
#                                 {'name': 'ap', 'sentiment': 'none'}],
#               'persons': [{'name': 'mary clare jalonick', 'sentiment': 'none'},
#                           {'name': 'maguire', 'sentiment': 'none'},
#                           {'name': 'donald trump', 'sentiment': 'none'},
#                           {'name': 'joseph maguire', 'sentiment': 'none'},
# ...

# %%
df2_list = []
for file in combinedfiles:
    df2_list.append(combinedfiles['thread'])
df2_list
    
# df2 = pd.concat(df2_list, ignore_index=True)
# # df2

# x = df2

# x = json.load(f)
# df4 = pd.DataFrame.from_dict(x, orient='index')
# df4
# Out:
# [{'uuid': '5b9798d8d56edd89b6f7356bf59205217040be3b',
#   'url': 'https://www.kqed.org/tv/programs/index.jsp?pgmid=24951',
#   'site_full': 'www.kqed.org',
#   'site': 'kqed.org',
#   'site_section': 'http://www.kqed.org/servlets/RSS?id=H',
#   'site_categories': ['media'],
#   'section_title': 'KQED 9 Daily Schedule',
#   'title': '09:30 PM: Happy Valley',
#   'title_full': '09:30 PM: Happy Valley',
#   'published': '2019-09-27T07:30:00.000+03:00',
#   'replies_count': 0,
#   'participants_count': 0,
#   'site_type': 'news',
#   'country': 'US',
#   'spam_score': 0.0,
#   'main_image': 'http://a.s.kqed.net/img/nav/og-tv.png',
#   'performance_score': 0,
#   'domain_rank': 14446,
#   'social': {'facebook': {'likes': 0, 'comments': 0, 'shares': 0},
#    'gplus': {'shares': 0},
#    'pinterest': {'shares': 0},
#    'linkedin': {'shares': 0},
#    'stumbledupon': {'shares': 0},
#    'vk': {'shares': 0}}},
#  {'uuid': '5b9798d8d56edd89b6f7356bf59205217040be3b',
# ...
