# %%
# %matplotlib notebook

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import json
from pprint import pprint

# Import API key
from config import api_key

base_url = "https://api.nytimes.com/svc/archive/v1/"

# %%
#queries
startYear = "1852"
startMonth = "1"

# %%
#reset articleCount
articleCount = []

#Calling APIs
query_url = base_url + startYear+ "/" + startMonth + ".json?" + "api-key=" + api_key 
articles = requests.get(query_url).json()
articles = articles['response']['docs']
pprint(articles)
# Out:
# [{'_id': '4fbfd31a45c1498b0d0094ef',
#   'abstract': None,
#   'blog': [],
#   'byline': None,
#   'document_type': 'article',
#   'headline': {'kicker': '1', 'main': 'Article 1 -- No Title'},
#   'keywords': [],
#   'lead_paragraph': None,
#   'multimedia': [],
#   'news_desk': None,
#   'print_page': '2',
#   'pub_date': '1852-01-01T00:03:58Z',
#   'section_name': None,
#   'slideshow_credits': None,
#   'snippet': None,
#   'source': 'The New York Times',
#   'subsection_name': None,
#   'type_of_material': 'Article',
#   'web_url': 'https://query.nytimes.com/gst/abstract.html?res=9E00E2DC1331E234BC4953DFB7668389649FDE',
#   'word_count': 17},
#  {'_id': '4fbfd31a45c1498b0d0094f5',
#   'abstract': None,
#   'blog': [],
#   'byline': None,
#   'document_type': 'article',
#   'headline': {'kicker': '1', 'main': 'France and Great Britain.'},
#   'keywords': [],
#   'lead_paragraph': 'LOUIS NAPOLEON just now seems omnipotent in France. He '
#                     'has the army on his side, at his bidding. That vast body '
#                     'of armed men perpetrates the grossest outrages upon law, '
#                     'and tramples alike upon personal and public rights.',
#   'multimedia': [],
#   'news_desk': None,
#   'print_page': '4',
#   'pub_date': '1852-01-01T00:03:58Z',
#   'section_name': None,
#   'slideshow_credits': None,
#   'snippet': 'LOUIS NAPOLEON just now seems omnipotent in France. He has the '
#              'army on his side, at his bidding. That vast body of armed men '
#              'perpetrates the grossest outrages upon law, and tramples alike '
#              'upon personal and public rights....',
#   'source': 'The New York Times',
#   'subsection_name': None,
#   'type_of_material': 'Article',
#   'web_url': 'https://query.nytimes.com/gst/abstract.html?res=9C02E2DC1331E234BC4953DFB7668389649FDE',
#   'word_count': 756},
#  {'_id': '4fbfd33145c1498b0d009850',
#   'abstract': None,
#   'blog': [],
#   'byline': None,
#   'document_type': 'article',
#   'headline': {'kicker': '1', 'main': 'Article 9 -- No Title'},
#   'keywords': [],
#   'lead_paragraph': None,
#   'multimedia': [],
#   'news_desk': None,
#   'print_page': '8',
#   'pub_date': '1852-01-01T00:03:58Z',
#   'section_name': None,
#   'slideshow_credits': None,
#   'snippet': None,
#   'source': 'The New York Times',
#   'subsection_name': None,
#   'type_of_material': 'Article',
#   'web_url': 'https://query.nytimes.com/gst/abstract.html?res=9A04E1DC1331E234BC4953DFB7668389649FDE',
#   'word_count': 339},
#  {'_id': '4fbfd31a45c1498b0d0094ee',
#   'abstract': None,
#   'blog': [],
#   'byline': None,
#   'document_type': 'article',
#   'headline': {'kicker': '1', 'main': 'Markets'},
#   'keywords': [],
#   'lead_paragraph': None,
#   'multimedia': [],
#   'news_desk': None,
#   'print_page': '4',
#   'pub_date': '1852-01-01T00:03:58Z',
#   'section_name': None,
#   'slideshow_credits': None,
#   'snippet': None,
#   'source': 'The New York Times',
#   'subsection_name': None,
#   'type_of_material': 'Article',
#   'web_url': 'https://query.nytimes.com/gst/abstract.html?res=980DE2DC1331E234BC4953DFB7668389649FDE',
#   'word_count': 51},
#  {'_id': '4fbfd31a45c1498b0d0094f4',
#   'abstract': None,
#   'blog': [],
#   'byline': None,
#   'document_type': 'article',
#   'headline': {'kicker': '1', 'main': 'THE LAST QUARTER OF THE YEAR 1850.'},
#   'keywords': [],
#   'lead_paragraph': 'OCTOBER. --The Danish war is bloody and disastrous. '
#                     'Several attempts are made by the Schleswig-Holstein Army '
#                     'to storm the city of FRIEDERICHSTADT, none of which prove '
#                     'successful. The losses sustained by the besieging force '
#                     'are very considerable.',
#   'multimedia': [],
#   'news_desk': None,
#   'print_page': '2',
#   'pub_date': '1852-01-01T00:03:58Z',
#   'section_name': None,
#   'slideshow_credits': None,
#   'snippet': 'OCTOBER. --The Danish war is bloody and disastrous. Several '
#              'attempts are made by the Schleswig-Holstein Army to storm the '
#              'city of FRIEDERICHSTADT, none of which prove successful. The '
#              'losses sustained by the besieging force are very '
#              'considerable....',
#   'source': 'The New York Times',
#   'subsection_name': None,
#   'type_of_material': 'Article',
#   'web_url': 'https://query.nytimes.com/gst/abstract.html?res=9C00E2DC1331E234BC4953DFB7668389649FDE',
#   'word_count': 1471},
#  {'_id': '4fbfd31a45c1498b0d009509',
#   'abstract': None,
#   'blog': [],
#   'byline': None,
#   'document_type': 'article',
#   'headline': {'kicker': '1', 'main': 'Article 5 -- No Title'},
#   'keywords': [],
#   'lead_paragraph': 'Will the Editor of the Daily Times be kind enough to '
#                     "inform his readers whence the quotation in this morning's "
#                     'Express--Time Danaos et dona preventes--is drawn, and '
#                     'what is the meaning? New-York, Dec. 31, 1851.',
#   'multimedia': [],
#   'news_desk': None,
#   'print_page': '4',
#   'pub_date': '1852-01-01T00:03:58Z',
#   'section_name': None,
#   'slideshow_credits': None,
#   'snippet': 'Will the Editor of the Daily Times be kind enough to inform his '
#              "readers whence the quotation in this morning's Express--Time "
#              'Danaos et dona preventes--is drawn, and what is the meaning? '
#              'New-York, Dec. 31, 1851....',
#   'source': 'The New York Times',
#   'subsection_name': None,
#   'type_of_material': 'Article',
#   'web_url': 'https://query.nytimes.com/gst/abstract.html?res=9E02E2DC1331E234BC4953DFB7668389649FDE',
#   'word_count': 111},
#  {'_id': '4fbfd33145c1498b0d00984b',
#   'abstract': None,
#   'blog': [],
#   'byline': {'original': 'CATHERINE N. FORREST vs. EDWIN FORREST',
#              'person': [{'firstname': 'Catherine',
#                          'lastname': 'FORREST',
#                          'middlename': 'N.',
#                          'organization': '',
#                          'rank': 1,
#                          'role': 'reported'}]},
#   'document_type': 'article',
#   'headline': {'kicker': '1',
#                'main': 'The Forrest Case on Trial.; SUPERIOR COURT--Before '
#                        'Chief Justice OAKLEY and a Special Jury.'},
#   'keywords': [],
#   'lead_paragraph': 'TWELFTH DAY. The ardor of the spectators was not cooled '
#                     'by the unpropitious state of the weather this morning, '
#                     'for the room was full as usual. Mrs. Forrest and Mrs. N. '
#                     "P. Willis arrived with Mr. O'Conor at 10 o'clock, and Mr. "
#                     'Forrest and his friends shortly after.',
#   'multimedia': [],
#   'news_desk': None,
#   'print_page': '5',
#   'pub_date': '1852-01-01T00:03:58Z',
#   'section_name': None,
#   'slideshow_credits': None,
#   'snippet': 'TWELFTH DAY. The ardor of the spectators was not cooled by the '
#              'unpropitious state of the weather this morning, for the room was '
#              'full as usual. Mrs. Forrest and Mrs. N. P. Willis arrived with '
#              "Mr. O'Conor at 10 o'clock, and Mr. Forrest and his frien...",
#   'source': 'The New York Times',
#   'subsection_name': None,
#   'type_of_material': 'Article',
#   'web_url': 'https://query.nytimes.com/gst/abstract.html?res=9E0CE2DC1331E234BC4953DFB7668389649FDE',
#   'word_count': 1208},
#  {'_id': '4fbfd33145c1498b0d009851',
#   'abstract': None,
#   'blog': [],
#   'byline': None,
#   'document_type': 'article',
#   'headline': {'kicker': '1',
#                'main': 'XXXIId CONGRESS.....First Session.; HOUSE OF '
#                        'REPRESENTATIVES.'},
#   'keywords': [],
#   'lead_paragraph': 'THE RECEPTION OF KOSSUTH. Various questions of order were '
#                     "raised on Mr. CLINGMAN'S resolution to stay the debate in "
#                     'half an hour on the resolution for the appointment of a '
#                     'committee of five to wait on KOSSUTH and introduce him to '
#                     'the House. The Yeas and Nays were called several times '
#                     'before the question was disposed of.',
#   'multimedia': [],
#   'news_desk': None,
#   'print_page': '4',
#   'pub_date': '1852-01-01T00:03:58Z',
#   'section_name': None,
#   'slideshow_credits': None,
#   'snippet': 'THE RECEPTION OF KOSSUTH. Various questions of order were raised '
#              "on Mr. CLINGMAN'S resolution to stay the debate in half an hour "
#              'on the resolution for the appointment of a committee of five to '
#              'wait on KOSSUTH and introduce him to the House. The Ye...',
#   'source': 'The New York Times',
#   'subsection_name': None,
#   'type_of_material': 'Article',
#   'web_url': 'https://query.nytimes.com/gst/abstract.html?res=9502E2DC1331E234BC4953DFB7668389649FDE',
#   'word_count': 1516},
#  {'_id': '4fbfd35145c1498b0d00a8ff',
#   'abstract': 'Lectures on the Crystal Palace',
#   'blog': [],
#   'byline': {'original': 'A LECTURE... BY HORACE GREELEY',
#              'person': [{'organization': '', 'rank': 1, 'role': 'reported'}]},
#   'document_type': 'article',
#   'headline': {'main': 'The Crystal Palace and its Lessons.'},
#   'keywords': [{'name': 'persons', 'value': 'GREELEY, HORACE'}],
#   'lead_paragraph': 'Hon. HORACE GREELEY delivered a lecture before the '
#                     'Philomathean Society of Brooklyn, on Tuesday evening. His '
#                     'subject was the "World\'s Fair and its Lessons." The '
#                     'following is a summary of his remarks: Each age, each '
#                     'race, inscribes itself, with more or less distinctness, '
#                     "on History's dial.",
#   'multimedia': [],
#   'news_desk': None,
#   'print_page': '6',
#   'pub_date': '1852-01-01T00:03:58Z',
#   'section_name': None,
#   'slideshow_credits': None,
#   'snippet': 'Hon. HORACE GREELEY delivered a lecture before the Philomathean '
#              'Society of Brooklyn, on Tuesday evening. His subject was the '
#              '"World\'s Fair and its Lessons." The following is a summary of '
#              'his remarks: Each age, each race, inscribes itself, with mor...',
#   'source': 'The New York Times',
#   'subsection_name': None,
#   'type_of_material': 'Article',
#   'web_url': 'https://query.nytimes.com/gst/abstract.html?res=9F05E1DC1331E234BC4953DFB7668389649FDE',
#   'word_count': 2818},
#  {'_id': '4fbfd31245c1498b0d0091b9',
#   'abstract': None,
#   'blog': [],
#   'byline': None,
#   'document_type': 'article',
#   'headline': {'kicker': '1', 'main': 'DIED.'},
#   'keywords': [],
#   'lead_paragraph': 'On the morning of the 31st, in the 20th year of her age, '
#                     'MARY H., only daughter of William T. and E. H. Cock The '
#                     'friends and acquaintances of the family are respectfully '
#                     "invited to attend her funeral, at the Friends' "
#                     'Meeting-house. Westbury, L. I., on sixth day morning, at '
#                     '11 A. M. Carriages will be in attendance at Carle-place, '
#                     'to meet the cars on that morning.',
#   'multimedia': [],
#   'news_desk': None,
#   'print_page': '5',
#   'pub_date': '1852-01-01T00:03:58Z',
#   'section_name': None,
#   'slideshow_credits': None,
#   'snippet': 'On the morning of the 31st, in the 20th year of her age, MARY '
#              'H., only daughter of William T. and E. H. Cock The friends and '
#              'acquaintances of the family are respectfully invited to attend '
#              "her funeral, at the Friends' Meeting-house. Westbury, L. I....",
#   'source': 'The New York Times',
#   'subsection_name': None,
#   'type_of_material': 'Obituary',
#   'web_url': 'https://query.nytimes.com/gst/abstract.html?res=980CE2DC1331E234BC4953DFB7668389649FDE',
#   'word_count': 178},
#  {'_id': '4fbfd31a45c1498b0d0094ed',
#   'abstract': None,
#   'blog': [],
#   'byline': None,
#   'document_type': 'article',
#   'headline': {'kicker': '1', 'main': 'MINIATURE ALMANAC....THIS DAY.'},
#   'keywords': [],
#   'lead_paragraph': None,
#   'multimedia': [],
#   'news_desk': None,
#   'print_page': '8',
#   'pub_date': '1852-01-01T00:03:58Z',
#   'section_name': None,
#   'slideshow_credits': None,
#   'snippet': None,
#   'source': 'The New York Times',
#   'subsection_name': None,
#   'type_of_material': 'Article',
#   'web_url': 'https://query.nytimes.com/gst/abstract.html?res=9D07E1DC1331E234BC4953DFB7668389649FDE',
#   'word_count': 31},
#  {'_id': '4fbfd31a45c1498b0d0094f3',
#   'abstract': None,
#   'blog': [],
#   'byline': None,
#   'document_type': 'article',
#   'headline': {'kicker': '1', 'main': 'Kossuth in Washington.'},
#   'keywords': [],
#   'lead_paragraph': None,
#   'multimedia': [],
#   'news_desk': None,
#   'print_page': '4',
#   'pub_date': '1852-01-01T00:03:58Z',
#   'section_name': None,
#   'slideshow_credits': None,
#   'snippet': None,
#   'source': 'The New York Times',
#   'subsection_name': None,
#   'type_of_material': 'Article',
#   'web_url': 'https://query.nytimes.com/gst/abstract.html?res=9C0DE2DC1331E234BC4953DFB7668389649FDE',
#   'word_count': 69},
#  {'_id': '4fbfd31a45c1498b0d0094fc',
#   'abstract': None,
#   'blog': [],
#   'byline': None,
#   'document_type': 'article',
#   'headline': {'kicker': '1',
#                'main': 'Official Communication from the French Minister.'},
#   'keywords': [],
#   'lead_paragraph': 'The Intelligencer says that his Excellency the Minister '
#                     'from France, called yesterday at the Department of State, '
#                     'by direction of his Government, to officially announce '
#                     'that the President of the French Republic had adopted the '
#                     'great measure for the public safety.',
#   'multimedia': [],
#   'news_desk': None,
#   'print_page': '4',
#   'pub_date': '1852-01-01T00:03:58Z',
#   'section_name': None,
#   'slideshow_credits': None,
#   'snippet': 'The Intelligencer says that his Excellency the Minister from '
#              'France, called yesterday at the Department of State, by '
#              'direction of his Government, to officially announce that the '
#              'President of the French Republic had adopted the great measure '
#              'for th...',
#   'source': 'The New York Times',
#   'subsection_name': None,
#   'type_of_material': 'Article',
#   'web_url': 'https://query.nytimes.com/gst/abstract.html?res=9D0DE2DC1331E234BC4953DFB7668389649FDE',
#   'word_count': 191},
#  {'_id': '4fbfd31a45c1498b0d009508',
#   'abstract': None,
#   'blog': [],
#   'byline': None,
#   'document_type': 'article',
#   'headline': {'kicker': '1', 'main': 'Reports of the Weather Yesterday.'},
#   'keywords': [],
#   'lead_paragraph': 'ALBANY.--It has been raining here hard all day. The water '
#                     'in the river is very high and still rising rapidly. All '
#                     'communication with the opposite side is discontinued on '
#                     'account of the uncertain state of the ice. Every '
#                     'preparation has been made for the breaking up of the ice '
#                     'and a heavy freshet, which is anticipated before morning.',
#   'multimedia': [],
#   'news_desk': None,
#   'print_page': '4',
#   'pub_date': '1852-01-01T00:03:58Z',
#   'section_name': None,
#   'slideshow_credits': None,
#   'snippet': 'ALBANY.--It has been raining here hard all day. The water in the '
#              'river is very high and still rising rapidly. All communication '
#              'with the opposite side is discontinued on account of the '
#              'uncertain state of the ice. Every preparation has been made '
#              'fo...',
#   'source': 'The New York Times',
#   'subsection_name': None,
#   'type_of_material': 'Article',
#   'web_url': 'https://query.nytimes.com/gst/abstract.html?res=9F0DE2DC1331E234BC4953DFB7668389649FDE',
#   'word_count': 264},
#  {'_id': '4fbfd31b45c1498b0d0097ed',
#   'abstract': 'Letter resigning his seat in the Senate',
#   'blog': [],
#   'byline': None,
#   'document_type': 'article',
#   'headline': {'main': "Mr. Clay's Letter of Resignation."},
#   'keywords': [{'name': 'persons', 'value': 'CLAY, HENRY'}],
#   'lead_paragraph': 'To the General Assembly of Kentucky: When you did the '
#                     'honor to confer on me the appointment of a Senator from '
#                     'Kentucky, which I now hold, in accepting it I did not '
#                     'intend or expect to serve the entire term of six years. I '
#                     'had previously retired.',
#   'multimedia': [],
#   'news_desk': None,
#   'print_page': '4',
#   'pub_date': '1852-01-01T00:03:58Z',
#   'section_name': None,
#   'slideshow_credits': None,
#   'snippet': 'To the General Assembly of Kentucky: When you did the honor to '
#              'confer on me the appointment of a Senator from Kentucky, which I '
#              'now hold, in accepting it I did not intend or expect to serve '
#              'the entire term of six years. I had previously retired....',
#   'source': 'The New York Times',
#   'subsection_name': None,
#   'type_of_material': 'Article',
#   'web_url': 'https://query.nytimes.com/gst/abstract.html?res=9A0DE2DC1331E234BC4953DFB7668389649FDE',
#   'word_count': 386},
#  {'_id': '4fbfd33145c1498b0d00984c',
#   'abstract': None,
#   'blog': [],
#   'byline': {'original': 'Correspondence of The New-York Daily Times',
#              'person': [{'organization': '', 'rank': 1, 'role': 'reported'}]},
#   'document_type': 'article',
#   'headline': {'kicker': '1',
#                'main': 'ENGLAND.; The French Revolution--Marshal Soult--A '
#                        'Trial for Swindling--International Copyright--Railway '
#                        'Accidents--Education--Customs Reform--Search for Capt. '
#                        'Franklin--Dr. Lardner--City Burying Grounds, &c., &c., '
#                        '&c.'},
#   'keywords': [],
#   'lead_paragraph': 'The sluggish current of events was thoroughly stirred and '
#                     'troubled on Tuesday by the startling intelligence of '
#                     "another coup d'etat in Paris, not yet indeed amounting to "
#                     'a sanguinary revolution, but very possibly shadowing '
#                     'forth such a fearful occurrence.',
#   'multimedia': [],
#   'news_desk': None,
#   'print_page': '6',
#   'pub_date': '1852-01-01T00:03:58Z',
#   'section_name': None,
#   'slideshow_credits': None,
#   'snippet': 'The sluggish current of events was thoroughly stirred and '
#              'troubled on Tuesday by the startling intelligence of another '
#              "coup d'etat in Paris, not yet indeed amounting to a sanguinary "
#              'revolution, but very possibly shadowing forth such a fearful '
#              'occu...',
#   'source': 'The New York Times',
#   'subsection_name': None,
#   'type_of_material': 'Article',
#   'web_url': 'https://query.nytimes.com/gst/abstract.html?res=9905E1DC1331E234BC4953DFB7668389649FDE',
#   'word_count': 3159},
#  {'_id': '4fbfd31245c1498b0d0091b8',
#   'abstract': None,
#   'blog': [],
#   'byline': None,
#   'document_type': 'article',
#   'headline': {'kicker': '1',
#                'main': 'Scientific Intelligence.; Prepared for The New-York '
#                        'Daily Times.'},
#   'keywords': [],
#   'lead_paragraph': '--AT A LATE MEETING of the Royal Society of Literature in '
#                     'London, an interesting paper on some Roman Antiquities, '
#                     'recently discovered by Dr. Barth in Western Africa, was '
#                     'presented by Mr. J. Hogg. The place where the relics in '
#                     'question were found, is named Ghareeah el Gharbeeah (the '
#                     'Western Ghareeah) and is situated, according to Mr. '
#                     "Hogg's calculation, about 160 miles south of Tripoli.",
#   'multimedia': [],
#   'news_desk': None,
#   'print_page': '6',
#   'pub_date': '1852-01-01T00:03:58Z',
#   'section_name': None,
#   'slideshow_credits': None,
#   'snippet': '--AT A LATE MEETING of the Royal Society of Literature in '
#              'London, an interesting paper on some Roman Antiquities, recently '
#              'discovered by Dr. Barth in Western Africa, was presented by Mr. '
#              'J. Hogg. The place where the relics in question were found, ...',
#   'source': 'The New York Times',
#   'subsection_name': None,
#   'type_of_material': 'Article',
#   'web_url': 'https://query.nytimes.com/gst/abstract.html?res=9B05E1DC1331E234BC4953DFB7668389649FDE',
#   'word_count': 1519},
#  {'_id': '4fbfd31a45c1498b0d0094ec',
#   'abstract': None,
#   'blog': [],
#   'byline': {'original': 'Correspondence of the New-York Daily Times',
#              'person': [{'organization': '', 'rank': 1, 'role': 'reported'}]},
#   'document_type': 'article',
#   'headline': {'kicker': '1',
#                'main': 'CALIFORNIA.; The Sandwich Island Movement--Growth of '
#                        'Crime--Society in El Dorado, &c.'},
#   'keywords': [],
#   'lead_paragraph': 'Unforeseen circumstances have interposed so many barriers '
#                     'to the exercise of my epistolary functions, that I shall '
#                     'acquit myself most poorly in this my second visit to the '
#                     '"Times." I have but about an hour left, and of course '
#                     'must run through a hurried review of matters occurring '
#                     'since I wrote before.',
#   'multimedia': [],
#   'news_desk': None,
#   'print_page': '6',
#   'pub_date': '1852-01-01T00:03:58Z',
#   'section_name': None,
#   'slideshow_credits': None,
#   'snippet': 'Unforeseen circumstances have interposed so many barriers to the '
#              'exercise of my epistolary functions, that I shall acquit myself '
#              'most poorly in this my second visit to the "Times." I have but '
#              'about an hour left, and of course must run through a hu...',
#   'source': 'The New York Times',
#   'subsection_name': None,
#   'type_of_material': 'Article',
#   'web_url': 'https://query.nytimes.com/gst/abstract.html?res=9A05E1DC1331E234BC4953DFB7668389649FDE',
#   'word_count': 825},
#  {'_id': '4fbfd31a45c1498b0d0094f2',
#   'abstract': None,
#   'blog': [],
#   'byline': None,
#   'document_type': 'article',
#   'headline': {'kicker': '1', 'main': 'The Irish Exiles.'},
#   'keywords': [],
#   'lead_paragraph': 'To the Editor of the New-York Daily Times: The friends of '
#                     "Smith O'Brien, Mitchell, and Meagher in this country, "
#                     'feel indignant at the use which is being made by certain '
#                     'designing parties of the names of these distinguished '
#                     'men, in order to excite in the minds of Irishmen in '
#                     'America a prejudice against KOSSUTH and his cause.',
#   'multimedia': [],
#   'news_desk': None,
#   'print_page': '3',
#   'pub_date': '1852-01-01T00:03:58Z',
#   'section_name': None,
#   'slideshow_credits': None,
#   'snippet': 'To the Editor of the New-York Daily Times: The friends of Smith '
#              "O'Brien, Mitchell, and Meagher in this country, feel indignant "
#              'at the use which is being made by certain designing parties of '
#              'the names of these distinguished men, in order to excite ...',
#   'source': 'The New York Times',
#   'subsection_name': None,
#   'type_of_material': 'Letter',
#   'web_url': 'https://query.nytimes.com/gst/abstract.html?res=9B00E2DC1331E234BC4953DFB7668389649FDE',
#   'word_count': 490},
#  {'_id': '4fbfd31a45c1498b0d009507',
#   'abstract': None,
#   'blog': [],
#   'byline': {'original': 'Correspondence of The New-York Daily Times',
#              'person': [{'organization': '', 'rank': 1, 'role': 'reported'}]},
#   'document_type': 'article',
#   'headline': {'kicker': '1',
#                'main': 'WESTERN NEW-YORK.; Railroads - Morsels -- Weather.'},
#   'keywords': [],
#   'lead_paragraph': 'However the mass of your readers may feel in the '
#                     'premises, you have undoubtedly a very lively personal '
#                     'interest in this particular locality, and they will hence '
#                     'pardon you for publishing even a very dull letter '
#                     'theranent.',
#   'multimedia': [],
#   'news_desk': None,
#   'print_page': '6',
#   'pub_date': '1852-01-01T00:03:58Z',
#   'section_name': None,
#   'slideshow_credits': None,
#   'snippet': 'However the mass of your readers may feel in the premises, you '
#              'have undoubtedly a very lively personal interest in this '
#              'particular locality, and they will hence pardon you for '
#              'publishing even a very dull letter theranent....',
#   'source': 'The New York Times',
#   'subsection_name': None,
#   'type_of_material': 'Article',
#   'web_url': 'https://query.nytimes.com/gst/abstract.html?res=9805E1DC1331E234BC4953DFB7668389649FDE',
#   'word_count': 777},
#  {'_id': '4fbfd31245c1498b0d0091b7',
#   'abstract': None,
#   'blog': [],
#   'byline': None,
#   'document_type': 'article',
#   'headline': {'kicker': '1', 'main': 'Article 4 -- No Title'},
#   'keywords': [],
#   'lead_paragraph': '"Ambrose Rose, entrusted with the regulation of the Cars '
#                     'after their arrival from the West, picked up a wallet '
#                     'containing some $700 Wednesday night in one of the Cars. '
#                     'On Thursday the owner called to inquire if anything had '
#                     'been heard of the wallet, when it was handed over to '
#                     'him--all right."--Albany Journal.',
#   'multimedia': [],
#   'news_desk': None,
#   'print_page': '4',
#   'pub_date': '1852-01-01T00:03:58Z',
#   'section_name': None,
#   'slideshow_credits': None,
#   'snippet': '"Ambrose Rose, entrusted with the regulation of the Cars after '
#              'their arrival from the West, picked up a wallet containing some '
#              '$700 Wednesday night in one of the Cars. On Thursday the owner '
#              'called to inquire if anything had been heard of the walle...',
#   'source': 'The New York Times',
#   'subsection_name': None,
#   'type_of_material': 'Article',
#   'web_url': 'https://query.nytimes.com/gst/abstract.html?res=9D02E2DC1331E234BC4953DFB7668389649FDE',
#   'word_count': 360},
#  {'_id': '4fbfd31a45c1498b0d0094f1',
#   'abstract': None,
#   'blog': [],
#   'byline': {'original': 'Correspondence of the New-York Daily Times',
#              'person': [{'organization': '', 'rank': 1, 'role': 'reported'}]},
#   'document_type': 'article',
#   'headline': {'kicker': '1',
#                'main': 'PHILADELPHIA.; Commencement of the Female Medical '
#                        'College--The Steamer City of Pittsburg.'},
#   'keywords': [],
#   'lead_paragraph': 'At the Musical Fund Hall this morning, the first public '
#                     'commencement of the Female Medical College of '
#                     'Philadelphia, took place. Large numbers of our young '
#                     'gentlemen medical students were present, and behaved '
#                     'themselves in a very creditable manner. The names of the '
#                     'ladies who graduated, are as follows:- Hannah E. '
#                     'Longshore.',
#   'multimedia': [],
#   'news_desk': None,
#   'print_page': '6',
#   'pub_date': '1852-01-01T00:03:58Z',
#   'section_name': None,
#   'slideshow_credits': None,
#   'snippet': 'At the Musical Fund Hall this morning, the first public '
#              'commencement of the Female Medical College of Philadelphia, took '
#              'place. Large numbers of our young gentlemen medical students '
#              'were present, and behaved themselves in a very creditable '
#              'manner....',
#   'source': 'The New York Times',
#   'subsection_name': None,
#   'type_of_material': 'Article',
#   'web_url': 'https://query.nytimes.com/gst/abstract.html?res=9405E1DC1331E234BC4953DFB7668389649FDE',
#   'word_count': 237},
#  {'_id': '4fbfd31a45c1498b0d0094fa',
#   'abstract': None,
#   'blog': [],
#   'byline': None,
#   'document_type': 'article',
#   'headline': {'kicker': '2', 'main': 'LETTER FROM KOSSUTH.'},
#   'keywords': [],
#   'lead_paragraph': 'From the London Daily News. To the Chairman and Members '
#                     "of the Party who celebrated M. Kossuth's Liberation by a "
#                     'Banquet at Stockholm. GENTLEMEN: One of the circumstances '
#                     'which has most tended to console the in my expatriation, '
#                     "has been to find my country's cause appreciated in the "
#                     'most remote localities.',
#   'multimedia': [],
#   'news_desk': None,
#   'print_page': '4',
#   'pub_date': '1852-01-01T00:03:58Z',
#   'section_name': None,
#   'slideshow_credits': None,
#   'snippet': 'From the London Daily News. To the Chairman and Members of the '
#              "Party who celebrated M. Kossuth's Liberation by a Banquet at "
#              'Stockholm. GENTLEMEN: One of the circumstances which has most '
#              'tended to console the in my expatriation, has been to find my...',
#   'source': 'The New York Times',
#   'subsection_name': None,
#   'type_of_material': 'Article',
#   'web_url': 'https://query.nytimes.com/gst/abstract.html?res=950DE2DC1331E234BC4953DFB7668389649FDE',
#   'word_count': 2163},
#  {'_id': '4fbfd31a45c1498b0d009506',
#   'abstract': None,
#   'blog': [],
#   'byline': None,
#   'document_type': 'article',
#   'headline': {'kicker': '1', 'main': 'TOPICS OF THE DAY.'},
#   'keywords': [],
#   'lead_paragraph': 'The Courier directs attention to its ample French '
#                     'correspondence. Paris, says the Editor, is indeed a '
#                     'strange city, as full of actual as the Bagdad o eminent '
#                     'story was of imaginary romance. * * * "Carnival is '
#                     'coming, and Paris, in spite of its sufferings, will soon '
#                     'be as blithesome as ever.',
#   'multimedia': [],
#   'news_desk': None,
#   'print_page': '5',
#   'pub_date': '1852-01-01T00:03:58Z',
#   'section_name': None,
#   'slideshow_credits': None,
#   'snippet': 'The Courier directs attention to its ample French '
#              'correspondence. Paris, says the Editor, is indeed a strange '
#              'city, as full of actual as the Bagdad o eminent story was of '
#              'imaginary romance. * * * "Carnival is coming, and Paris, in '
#              'spite of its suf...',
#   'source': 'The New York Times',
#   'subsection_name': None,
#   'type_of_material': 'Article',
#   'web_url': 'https://query.nytimes.com/gst/abstract.html?res=9D0CE2DC1331E234BC4953DFB7668389649FDE',
#   'word_count': 492},
#  {'_id': '4fbfd31245c1498b0d0091bf',
#   'abstract': None,
#   'blog': [],
#   'byline': {'original': 'Correspondence of The New-York Daily Times',
#              'person': [{'organization': '', 'rank': 1, 'role': 'reported'}]},
#   'document_type': 'article',
#   'headline': {'kicker': '1',
#                'main': 'WASHINGTON.; Congress and Kossuth--The Democratic '
#                        'National Convention--Prospects, &c.'},
#   'keywords': [],
#   'lead_paragraph': 'Inquiry is on foot as to the manner in which Congress '
#                     'will receive KOSSUTH. The Senate was very thin, to-day, '
#                     'but they adopted the report of the Committee, appointed '
#                     'some time ago, for the reception and introduction of '
#                     'KOSSUTH.',
#   'multimedia': [],
#   'news_desk': None,
#   'print_page': '3',
#   'pub_date': '1852-01-01T00:03:58Z',
#   'section_name': None,
#   'slideshow_credits': None,
#   'snippet': 'Inquiry is on foot as to the manner in which Congress will '
#              'receive KOSSUTH. The Senate was very thin, to-day, but they '
#              'adopted the report of the Committee, appointed some time ago, '
#              'for the reception and introduction of KOSSUTH....',
#   'source': 'The New York Times',
#   'subsection_name': None,
#   'type_of_material': 'Article',
#   'web_url': 'https://query.nytimes.com/gst/abstract.html?res=9900E2DC1331E234BC4953DFB7668389649FDE',
#   'word_count': 663},
#  {'_id': '4fbfd31a45c1498b0d0094f0',
#   'abstract': None,
#   'blog': [],
#   'byline': {'original': 'BY WILLIAM ROSS WALLACE',
#              'person': [{'firstname': 'William',
#                          'lastname': 'WALLACE',
#                          'middlename': 'Ross',
#                          'organization': '',
#                          'rank': 1,
#                          'role': 'reported'}]},
#   'document_type': 'article',
#   'headline': {'kicker': '1',
#                'main': 'GOVERNOR KOSSUTH IN AMERICA.; For the New-York Daily '
#                        'Times.'},
#   'keywords': [],
#   'lead_paragraph': None,
#   'multimedia': [],
#   'news_desk': None,
#   'print_page': '1',
#   'pub_date': '1852-01-01T00:03:58Z',
#   'section_name': None,
#   'slideshow_credits': None,
#   'snippet': None,
#   'source': 'The New York Times',
#   'subsection_name': None,
#   'type_of_material': 'Front Page',
#   'web_url': 'https://query.nytimes.com/gst/abstract.html?res=9D01E2DC1331E234BC4953DFB7668389649FDE',
#   'word_count': 479},
#  {'_id': '4fbfd31a45c1498b0d009505',
#   'abstract': None,
#   'blog': [],
#   'byline': None,
#   'document_type': 'article',
#   'headline': {'kicker': '1',
#                'main': 'KOSSUTH.; For the New-York Daily Times.'},
#   'keywords': [],
#   'lead_paragraph': None,
#   'multimedia': [],
#   'news_desk': None,
#   'print_page': '6',
#   'pub_date': '1852-01-01T00:03:58Z',
#   'section_name': None,
#   'slideshow_credits': None,
#   'snippet': None,
#   'source': 'The New York Times',
#   'subsection_name': None,
#   'type_of_material': 'Article',
#   'web_url': 'https://query.nytimes.com/gst/abstract.html?res=9D05E1DC1331E234BC4953DFB7668389649FDE',
#   'word_count': 118},
#  {'_id': '4fbfd31245c1498b0d0091be',
#   'abstract': None,
#   'blog': [],
#   'byline': None,
#   'document_type': 'article',
#   'headline': {'kicker': '1', 'main': 'Article 8 -- No Title'},
#   'keywords': [],
#   'lead_paragraph': None,
#   'multimedia': [],
#   'news_desk': None,
#   'print_page': '4',
#   'pub_date': '1852-01-01T00:03:58Z',
#   'section_name': None,
#   'slideshow_credits': None,
#   'snippet': None,
#   'source': 'The New York Times',
#   'subsection_name': None,
#   'type_of_material': 'Article',
#   'web_url': 'https://query.nytimes.com/gst/abstract.html?res=9B0DE2DC1331E234BC4953DFB7668389649FDE',
#   'word_count': 81},
#  {'_id': '4fbfd34c45c1498b0d009f59',
#   'abstract': None,
#   'blog': [],
#   'byline': None,
#   'document_type': 'article',
#   'headline': {'kicker': '1', 'main': 'FINANCIAL.'},
#   'keywords': [],
#   'lead_paragraph': None,
#   'multimedia': [],
#   'news_desk': None,
#   'print_page': '3',
#   'pub_date': '1852-01-01T00:03:58Z',
#   'section_name': None,
#   'slideshow_credits': None,
#   'snippet': None,
#   'source': 'The New York Times',
#   'subsection_name': None,
#   'type_of_material': 'Article',
#   'web_url': 'https://query.nytimes.com/gst/abstract.html?res=9803E2DC1331E234BC4953DFB7668389649FDE',
#   'word_count': 2131},
#  {'_id': '4fbfd31245c1498b0d0091bd',
#   'abstract': None,
#   'blog': [],
#   'byline': None,
#   'document_type': 'article',
#   'headline': {'kicker': '1', 'main': 'Article 7 -- No Title'},
#   'keywords': [],
#   'lead_paragraph': 'Distinguished gentlemen sometimes amuse themselves '
#                     'comically. General Waddy Thompson, of South Carolina, is '
#                     'on a visit to the Cherokee nation, collecting fees due '
#                     'him as an attorney, and the Cherokee Advocate says: '
#                     '"Quite a feat came off on Tuesday.',
#   'multimedia': [],
#   'news_desk': None,
#   'print_page': '4',
#   'pub_date': '1852-01-01T00:03:58Z',
#   'section_name': None,
#   'slideshow_credits': None,
#   'snippet': 'Distinguished gentlemen sometimes amuse themselves comically. '
#              'General Waddy Thompson, of South Carolina, is on a visit to the '
#              'Cherokee nation, collecting fees due him as an attorney, and the '
#              'Cherokee Advocate says: "Quite a feat came off on Tuesda...',
#   'source': 'The New York Times',
#   'subsection_name': None,
#   'type_of_material': 'Article',
#   'web_url': 'https://query.nytimes.com/gst/abstract.html?res=9902E2DC1331E234BC4953DFB7668389649FDE',
#   'word_count': 164},
#  {'_id': '4fbfd31a45c1498b0d009503',
#   'abstract': None,
#   'blog': [],
#   'byline': None,
#   'document_type': 'article',
#   'headline': {'kicker': '1', 'main': 'OFFICIAL STATE CANVASS.'},
#   'keywords': [],
#   'lead_paragraph': None,
#   'multimedia': [],
#   'news_desk': None,
#   'print_page': '7',
#   'pub_date': '1852-01-01T00:03:58Z',
#   'section_name': None,
#   'slideshow_credits': None,
#   'snippet': None,
#   'source': 'The New York Times',
#   'subsection_name': None,
#   'type_of_material': 'Article',
#   'web_url': 'https://query.nytimes.com/gst/abstract.html?res=9E04E1DC1331E234BC4953DFB7668389649FDE',
#   'word_count': 10072},
#  {'_id': '4fbfd34c45c1498b0d009f49',
#   'abstract': None,
#   'blog': [],
#   'byline': None,
#   'document_type': 'article',
#   'headline': {'kicker': '1', 'main': 'MARINE INTELLIGENCE.'},
#   'keywords': [],
#   'lead_paragraph': None,
#   'multimedia': [],
#   'news_desk': None,
#   'print_page': '8',
#   'pub_date': '1852-01-01T00:03:58Z',
#   'section_name': None,
#   'slideshow_credits': None,
#   'snippet': None,
#   'source': 'The New York Times',
#   'subsection_name': None,
#   'type_of_material': 'Article',
#   'web_url': 'https://query.nytimes.com/gst/abstract.html?res=9E07E1DC1331E234BC4953DFB7668389649FDE',
#   'word_count': 192},
#  {'_id': '4fbfd34c45c1498b0d009f58',
#   'abstract': None,
#   'blog': [],
#   'byline': None,
#   'document_type': 'article',
#   'headline': {'kicker': '1', 'main': 'From Albany--appointments.'},
#   'keywords': [],
#   'lead_paragraph': None,
#   'multimedia': [],
#   'news_desk': None,
#   'print_page': '4',
#   'pub_date': '1852-01-01T00:03:58Z',
#   'section_name': None,
#   'slideshow_credits': None,
#   'snippet': None,
#   'source': 'The New York Times',
#   'subsection_name': None,
#   'type_of_material': 'Article',
#   'web_url': 'https://query.nytimes.com/gst/abstract.html?res=9E0DE2DC1331E234BC4953DFB7668389649FDE',
#   'word_count': 48},
#  {'_id': '4fbfd31245c1498b0d0091bc',
#   'abstract': None,
#   'blog': [],
#   'byline': None,
#   'document_type': 'article',
#   'headline': {'kicker': '1', 'main': 'FRANCE.; Scenes of the Usurpation.'},
#   'keywords': [],
#   'lead_paragraph': 'To the Editor of The New-York Daily Times: On Tuesday '
#                     'morning, the 2nd day of this "bleak December," "While I '
#                     'nodded nearly napping, suddenly there came a tapping, As '
#                     'of some one loudly rapping, rapping at my chamber door; '
#                     'Tis some visitor, I muttered, knocking at my chamber '
#                     'door: Only this, and nothing more."',
#   'multimedia': [],
#   'news_desk': None,
#   'print_page': '3',
#   'pub_date': '1852-01-01T00:03:58Z',
#   'section_name': None,
#   'slideshow_credits': None,
#   'snippet': 'To the Editor of The New-York Daily Times: On Tuesday morning, '
#              'the 2nd day of this "bleak December," "While I nodded nearly '
#              'napping, suddenly there came a tapping, As of some one loudly '
#              'rapping, rapping at my chamber door; Tis some visitor, I mutt...',
#   'source': 'The New York Times',
#   'subsection_name': None,
#   'type_of_material': 'Letter',
#   'web_url': 'https://query.nytimes.com/gst/abstract.html?res=9800E2DC1331E234BC4953DFB7668389649FDE',
#   'word_count': 2266},
#  {'_id': '4fbfd31a45c1498b0d009502',
#   'abstract': None,
#   'blog': [],
#   'byline': None,
#   'document_type': 'article',
#   'headline': {'kicker': '1', 'main': 'PRINCIPAL EVENTS OF 1851.'},
#   'keywords': [],
#   'lead_paragraph': 'JANUARY. Jan. 1.--Comet discovered by W. C. Bond, '
#                     'Director of Cambridge Observatory, Mass.; the eleventh '
#                     'first seen at that point. R. A. 2h. 33 1/2m., S. Decl. '
#                     "4[degrees] 36' Comet very faint.",
#   'multimedia': [],
#   'news_desk': None,
#   'print_page': '2',
#   'pub_date': '1852-01-01T00:03:58Z',
#   'section_name': None,
#   'slideshow_credits': None,
#   'snippet': 'JANUARY. Jan. 1.--Comet discovered by W. C. Bond, Director of '
#              'Cambridge Observatory, Mass.; the eleventh first seen at that '
#              "point. R. A. 2h. 33 1/2m., S. Decl. 4[degrees] 36' Comet very "
#              'faint....',
#   'source': 'The New York Times',
#   'subsection_name': None,
#   'type_of_material': 'Article',
#   'web_url': 'https://query.nytimes.com/gst/abstract.html?res=9501E2DC1331E234BC4953DFB7668389649FDE',
#   'word_count': 5172},
#  {'_id': '4fbfd34c45c1498b0d009f48',
#   'abstract': None,
#   'blog': [],
#   'byline': None,
#   'document_type': 'article',
#   'headline': {'kicker': '1', 'main': 'NEW-YORK CITY.'},
#   'keywords': [],
#   'lead_paragraph': 'Licenses. The following table, showing the number of '
#                     "Licenses issued from the Mayor's office during the years "
#                     '1850 and 1857, has been compiled by ASHER TAYLOR, First '
#                     "Marshal in the Mayor's office:",
#   'multimedia': [],
#   'news_desk': None,
#   'print_page': '8',
#   'pub_date': '1852-01-01T00:03:58Z',
#   'section_name': None,
#   'slideshow_credits': None,
#   'snippet': 'Licenses. The following table, showing the number of Licenses '
#              "issued from the Mayor's office during the years 1850 and 1857, "
#              "has been compiled by ASHER TAYLOR, First Marshal in the Mayor's "
#              'office:...',
#   'source': 'The New York Times',
#   'subsection_name': None,
#   'type_of_material': 'Article',
#   'web_url': 'https://query.nytimes.com/gst/abstract.html?res=9504E1DC1331E234BC4953DFB7668389649FDE',
#   'word_count': 675},
#  {'_id': '4fbfd31245c1498b0d0091bb',
#   'abstract': None,
#   'blog': [],
#   'byline': {'original': 'Special Correspondence of The New-York Daily Times',
#              'person': [{'organization': '', 'rank': 1, 'role': 'reported'}]},
#   'document_type': 'article',
#   'headline': {'kicker': '1',
#                'main': 'Movements of Kossuth.; Gov. Lowe--The Proposed '
#                        "Corporation Banquet--The Hebrews' Gift--Mad. Kossuth "
#                        'and Mad. Pulazky.'},
#   'keywords': [],
#   'lead_paragraph': 'Much regret is felt that Governor LOWE, of Maryland, was '
#                     'not present at the reception of KOSSUTH. The letter '
#                     'dispatched to Annapolis, announcing the day when the '
#                     'distinguished guest would arrive, did not reach Gov. LOWE '
#                     'until too late.',
#   'multimedia': [],
#   'news_desk': None,
#   'print_page': '4',
#   'pub_date': '1852-01-01T00:03:58Z',
#   'section_name': None,
#   'slideshow_credits': None,
#   'snippet': 'Much regret is felt that Governor LOWE, of Maryland, was not '
#              'present at the reception of KOSSUTH. The letter dispatched to '
#              'Annapolis, announcing the day when the distinguished guest would '
#              'arrive, did not reach Gov. LOWE until too late....',
#   'source': 'The New York Times',
#   'subsection_name': None,
#   'type_of_material': 'Article',
#   'web_url': 'https://query.nytimes.com/gst/abstract.html?res=9802E2DC1331E234BC4953DFB7668389649FDE',
#   'word_count': 502},
#  {'_id': '4fbfd34c45c1498b0d009f47',
#   'abstract': None,
#   'blog': [],
#   'byline': None,
#   'document_type': 'article',
#   'headline': {'kicker': '1', 'main': 'Article 6 -- No Title'},
#   'keywords': [],
#   'lead_paragraph': None,
#   'multimedia': [],
#   'news_desk': None,
#   'print_page': '4',
#   'pub_date': '1852-01-01T00:03:58Z',
#   'section_name': None,
#   'slideshow_credits': None,
#   'snippet': None,
#   'source': 'The New York Times',
#   'subsection_name': None,
#   'type_of_material': 'Article',
#   'web_url': 'https://query.nytimes.com/gst/abstract.html?res=9F02E2DC1331E234BC4953DFB7668389649FDE',
#   'word_count': 42},
#  {'_id': '4fbfd34c45c1498b0d009f56',
#   'abstract': None,
#   'blog': [],
#   'byline': None,
#   'document_type': 'article',
#   'headline': {'kicker': '1', 'main': 'COAL.'},
#   'keywords': [],
#   'lead_paragraph': None,
#   'multimedia': [],
#   'news_desk': None,
#   'print_page': '3',
#   'pub_date': '1852-01-01T00:03:58Z',
#   'section_name': None,
#   'slideshow_credits': None,
#   'snippet': None,
#   'source': 'The New York Times',
#   'subsection_name': None,
#   'type_of_material': 'Article',
#   'web_url': 'https://query.nytimes.com/gst/abstract.html?res=9C03E2DC1331E234BC4953DFB7668389649FDE',
#   'word_count': 134},
#  {'_id': '4fbfd31245c1498b0d0091ba',
#   'abstract': None,
#   'blog': [],
#   'byline': None,
#   'document_type': 'article',
#   'headline': {'kicker': '1',
#                'main': 'Official Announcement of the late Movement in France.'},
#   'keywords': [],
#   'lead_paragraph': None,
#   'multimedia': [],
#   'news_desk': None,
#   'print_page': '4',
#   'pub_date': '1852-01-01T00:03:58Z',
#   'section_name': None,
#   'slideshow_credits': None,
#   'snippet': None,
#   'source': 'The New York Times',
#   'subsection_name': None,
#   'type_of_material': 'Article',
#   'web_url': 'https://query.nytimes.com/gst/abstract.html?res=990DE2DC1331E234BC4953DFB7668389649FDE',
#   'word_count': 169},
#  {'_id': '4fbfd34c45c1498b0d009f46',
#   'abstract': None,
#   'blog': [],
#   'byline': None,
#   'document_type': 'article',
#   'headline': {'kicker': '1',
#                'main': 'NEW-YORK CITY.; City Government. Hon. AMBROSE C. '
#                        'KINGSLAND, Mayor.'},
#   'keywords': [],
#   'lead_paragraph': None,
#   'multimedia': [],
#   'news_desk': None,
#   'print_page': '2',
#   'pub_date': '1852-01-01T00:03:58Z',
#   'section_name': None,
#   'slideshow_credits': None,
#   'snippet': None,
#   'source': 'The New York Times',
#   'subsection_name': None,
#   'type_of_material': 'Article',
#   'web_url': 'https://query.nytimes.com/gst/abstract.html?res=9D00E2DC1331E234BC4953DFB7668389649FDE',
#   'word_count': 2721},
#  {'_id': '4fbfd34c45c1498b0d009f4f',
#   'abstract': None,
#   'blog': [],
#   'byline': None,
#   'document_type': 'article',
#   'headline': {'kicker': '1', 'main': 'Article 3 -- No Title'},
#   'keywords': [],
#   'lead_paragraph': 'We have done with 1851. It has been fertile in events, '
#                     'whereof a full chronological summary will be found in our '
#                     'columns this morning. Very many distinguished men, in '
#                     'various parts of the world, have died during the '
#                     'year,--of whom brief biographical mention will also be '
#                     'found in this paper.',
#   'multimedia': [],
#   'news_desk': None,
#   'print_page': '4',
#   'pub_date': '1852-01-01T00:03:58Z',
#   'section_name': None,
#   'slideshow_credits': None,
#   'snippet': 'We have done with 1851. It has been fertile in events, whereof a '
#              'full chronological summary will be found in our columns this '
#              'morning. Very many distinguished men, in various parts of the '
#              'world, have died during the year,--of whom brief biographic...',
#   'source': 'The New York Times',
#   'subsection_name': None,
#   'type_of_material': 'Article',
#   'web_url': 'https://query.nytimes.com/gst/abstract.html?res=9503E2DC1331E234BC4953DFB7668389649FDE',
#   'word_count': 257},
#  {'_id': '4fbfd34c45c1498b0d009f55',
#   'abstract': None,
#   'blog': [],
#   'byline': None,
#   'document_type': 'article',
#   'headline': {'kicker': '1', 'main': 'Circulation of the Daily Times.'},
#   'keywords': [],
#   'lead_paragraph': None,
#   'multimedia': [],
#   'news_desk': None,
#   'print_page': '4',
#   'pub_date': '1852-01-01T00:03:58Z',
#   'section_name': None,
#   'slideshow_credits': None,
#   'snippet': None,
#   'source': 'The New York Times',
#   'subsection_name': None,
#   'type_of_material': 'Article',
#   'web_url': 'https://query.nytimes.com/gst/abstract.html?res=9B03E2DC1331E234BC4953DFB7668389649FDE',
#   'word_count': 618},
#  {'_id': '4fbfd34c45c1498b0d009f45',
#   'abstract': None,
#   'blog': [],
#   'byline': None,
#   'document_type': 'article',
#   'headline': {'kicker': '1', 'main': 'SPECIAL NOTICES.'},
#   'keywords': [],
#   'lead_paragraph': None,
#   'multimedia': [],
#   'news_desk': None,
#   'print_page': '5',
#   'pub_date': '1852-01-01T00:03:58Z',
#   'section_name': None,
#   'slideshow_credits': None,
#   'snippet': None,
#   'source': 'The New York Times',
#   'subsection_name': None,
#   'type_of_material': 'Article',
#   'web_url': 'https://query.nytimes.com/gst/abstract.html?res=9A0CE2DC1331E234BC4953DFB7668389649FDE',
#   'word_count': 1160},
#  {'_id': '4fbfd34c45c1498b0d009f4e',
#   'abstract': None,
#   'blog': [],
#   'byline': None,
#   'document_type': 'article',
#   'headline': {'kicker': '1', 'main': 'The Kossuth Banquet at Washington, &c.'},
#   'keywords': [],
#   'lead_paragraph': 'Immediately after the adjournment of the House, the '
# ...
#              'dispatch from Governor Hunt:...',
#   'source': 'The New York Times',
#   'subsection_name': None,
#   'type_of_material': 'Article',
#   'web_url': 'https://query.nytimes.com/gst/abstract.html?res=9C04E1D91431E13BBC4950DFB7668389649FDE',
#   'word_count': 2638},
#  {'_id': '4fbfd31245c1498b0d009287',
#   'abstract': None,
#   'blog': [],
#   'byline': None,
#   'document_type': 'article',
#   'headline': {'kicker': '1', 'main': 'COAL.'},
#   'keywords': [],
#   'lead_paragraph': None,
#   'multimedia': [],
#   'news_desk': None,
#   'print_page': '5',
#   'pub_date': '1852-01-31T00:03:58Z',
#   'section_name': None,
#   'slideshow_credits': None,
#   'snippet': None,
#   'source': 'The New York Times',
#   'subsection_name': None,
#   'type_of_material': 'Article',
#   'web_url': 'https://query.nytimes.com/gst/abstract.html?res=9806E1D91431E13BBC4950DFB7668389649FDE',
#   'word_count': 250},
#  {'_id': '4fbfd31b45c1498b0d00960e',
#   'abstract': None,
#   'blog': [],
#   'byline': {'original': 'Correspondence of The New-York Daily Times',
#              'person': [{'organization': '', 'rank': 1, 'role': 'reported'}]},
#   'document_type': 'article',
#   'headline': {'kicker': '1',
#                'main': 'RHODE ISLAND.; Politics of the Stnte--Kossuth '
#                        'FeelingEditors &c.'},
#   'keywords': [],
#   'lead_paragraph': '" Little Rhody," though the smallest in the Territory, is '
#                     'yet, in proportion to her population, the richest State '
#                     'in the Union: and Providence, relatively to its '
#                     'population, is the richest city in the world. There is an '
#                     'immense amount of old Hunkerism here in both political '
#                     'parties.',
#   'multimedia': [],
#   'news_desk': None,
#   'print_page': '6',
#   'pub_date': '1852-01-31T00:03:58Z',
#   'section_name': None,
#   'slideshow_credits': None,
#   'snippet': '" Little Rhody," though the smallest in the Territory, is yet, '
#              'in proportion to her population, the richest State in the Union: '
#              'and Providence, relatively to its population, is the richest '
#              'city in the world. There is an immense amount of old Hunke...',
#   'source': 'The New York Times',
#   'subsection_name': None,
#   'type_of_material': 'Article',
#   'web_url': 'https://query.nytimes.com/gst/abstract.html?res=9803E1D91431E13BBC4950DFB7668389649FDE',
#   'word_count': 380},
#  {'_id': '4fbfd31b45c1498b0d009614',
#   'abstract': None,
#   'blog': [],
#   'byline': None,
#   'document_type': 'article',
#   'headline': {'kicker': '1',
#                'main': 'Eternal Vigilance the Price of Liberty.'},
#   'keywords': [],
#   'lead_paragraph': 'To the Editor of The New-York Daily Times: It is said '
#                     'that the father of the brothers Rothschild, when upon his '
#                     'death bed, called them to his side, and first exerting '
#                     'his strength unsuccessfully to break a bundle of sticks, '
#                     'and then with ease snapping them singly, exemplified to '
#                     'his sons the advantage of union and the necessity of '
#                     'combination; a lesson, it is quite evident, they have '
#                     'well profited by.',
#   'multimedia': [],
#   'news_desk': None,
#   'print_page': '7',
#   'pub_date': '1852-01-31T00:03:58Z',
#   'section_name': None,
#   'slideshow_credits': None,
#   'snippet': 'To the Editor of The New-York Daily Times: It is said that the '
#              'father of the brothers Rothschild, when upon his death bed, '
#              'called them to his side, and first exerting his strength '
#              'unsuccessfully to break a bundle of sticks, and then with ease '
#              'snap...',
#   'source': 'The New York Times',
#   'subsection_name': None,
#   'type_of_material': 'Letter',
#   'web_url': 'https://query.nytimes.com/gst/abstract.html?res=9B0DE1D91431E13BBC4950DFB7668389649FDE',
#   'word_count': 711},
#  {'_id': '4fbfd31b45c1498b0d00980c',
#   'abstract': 'Expedition projected',
#   'blog': [],
#   'byline': {'original': 'Correspondence of the New-York Daily Times',
#              'person': [{'organization': '', 'rank': 1, 'role': 'reported'}]},
#   'document_type': 'article',
#   'headline': {'main': 'WASHINGTON.; The Japan Expedition--Mr. '
#                        'Giddings--Intervention. &c.'},
#   'keywords': [{'name': 'glocations', 'value': 'JAPAN'}],
#   'lead_paragraph': '" The reason for the uncommon energy displayed at our '
#                     'Navy Yards, is that our Government thinks it proper to '
#                     'send a large force to Japan, to back up our demands on '
#                     'the Emperor for the return of our seamen, and perhaps for '
#                     'the opening of more of his ports to our commerce. Last '
#                     'July,',
#   'multimedia': [],
#   'news_desk': None,
#   'print_page': '8',
#   'pub_date': '1852-01-31T00:03:58Z',
#   'section_name': None,
#   'slideshow_credits': None,
#   'snippet': '" The reason for the uncommon energy displayed at our Navy '
#              'Yards, is that our Government thinks it proper to send a large '
#              'force to Japan, to back up our demands on the Emperor for the '
#              'return of our seamen, and perhaps for the opening of more of '
#              'hi...',
#   'source': 'The New York Times',
#   'subsection_name': None,
#   'type_of_material': 'Article',
#   'web_url': 'https://query.nytimes.com/gst/abstract.html?res=9802E0D91431E13BBC4950DFB7668389649FDE',
#   'word_count': 506},
#  {'_id': '4fbfd31b45c1498b0d009812',
#   'abstract': 'Execution of',
#   'blog': [],
#   'byline': None,
#   'document_type': 'article',
#   'headline': {'main': 'Execution of Hiram Knickerbocker.'},
#   'keywords': [{'name': 'persons', 'value': 'KNICKERBOCKER, HIRAM'}],
#   'lead_paragraph': 'Hiram Knickerbocker was executed in the Jail Yard in this '
#                     'city to-day. for the murder of C. Harkner. He was calm '
#                     'and self-possessed when he appeared upon the scaffold and '
#                     'addressed the assemblage as follows:',
#   'multimedia': [],
#   'news_desk': None,
#   'print_page': '8',
#   'pub_date': '1852-01-31T00:03:58Z',
#   'section_name': None,
#   'slideshow_credits': None,
#   'snippet': 'Hiram Knickerbocker was executed in the Jail Yard in this city '
#              'to-day. for the murder of C. Harkner. He was calm and '
#              'self-possessed when he appeared upon the scaffold and addressed '
#              'the assemblage as follows:...',
#   'source': 'The New York Times',
#   'subsection_name': None,
#   'type_of_material': 'Article',
#   'web_url': 'https://query.nytimes.com/gst/abstract.html?res=9407E0D91431E13BBC4950DFB7668389649FDE',
#   'word_count': 243},
#  {'_id': '4fbfd31245c1498b0d009286',
#   'abstract': None,
#   'blog': [],
#   'byline': {'original': 'By Telegraph to the New-York Daily Times',
#              'person': [{'organization': '', 'rank': 1, 'role': 'reported'}]},
#   'document_type': 'article',
#   'headline': {'kicker': '1',
#                'main': 'LATE.ST INTELLIGENCE; KOSSUTH IN WESTERN PENNSYLVANIA. '
#                        'SPEECH TO THE PITTSBURG CLERGY.'},
#   'keywords': [],
#   'lead_paragraph': 'Rev. Dr. McGILL having addressed KOSSUTH on behalf of the '
#                     'Clergy of the city of Pittsburg, Gov. KOSSUTH replied as '
#                     "follows: REV'D. SIR: I receive with thankful heart, and "
#                     'with pious reverence, the welcome of the evangelical '
#                     'ministry of Pittsburg. Alleghany, and vicinity.',
#   'multimedia': [],
#   'news_desk': None,
#   'print_page': '1',
#   'pub_date': '1852-01-31T00:03:58Z',
#   'section_name': None,
#   'slideshow_credits': None,
#   'snippet': 'Rev. Dr. McGILL having addressed KOSSUTH on behalf of the Clergy '
#              'of the city of Pittsburg, Gov. KOSSUTH replied as follows: '
#              "REV'D. SIR: I receive with thankful heart, and with pious "
#              'reverence, the welcome of the evangelical ministry of Pittsburg. '
#              '...',
#   'source': 'The New York Times',
#   'subsection_name': None,
#   'type_of_material': 'Front Page',
#   'web_url': 'https://query.nytimes.com/gst/abstract.html?res=9B01E2D91431E13BBC4950DFB7668389649FDE',
#   'word_count': 1632},
#  {'_id': '4fbfd31245c1498b0d00928f',
#   'abstract': None,
#   'blog': [],
#   'byline': None,
#   'document_type': 'article',
#   'headline': {'kicker': '1', 'main': 'Steamer Alabama at Savannah.'},
#   'keywords': [],
#   'lead_paragraph': None,
#   'multimedia': [],
#   'news_desk': None,
#   'print_page': '8',
#   'pub_date': '1852-01-31T00:03:58Z',
#   'section_name': None,
#   'slideshow_credits': None,
#   'snippet': None,
#   'source': 'The New York Times',
#   'subsection_name': None,
#   'type_of_material': 'Article',
#   'web_url': 'https://query.nytimes.com/gst/abstract.html?res=9403E0D91431E13BBC4950DFB7668389649FDE',
#   'word_count': 31},
#  {'_id': '4fbfd31b45c1498b0d00960f',
#   'abstract': None,
#   'blog': [],
#   'byline': None,
#   'document_type': 'article',
#   'headline': {'kicker': '1', 'main': 'The Portsmonth Bank Robbers.'},
#   'keywords': [],
#   'lead_paragraph': None,
#   'multimedia': [],
#   'news_desk': None,
#   'print_page': '8',
#   'pub_date': '1852-01-31T00:03:58Z',
#   'section_name': None,
#   'slideshow_credits': None,
#   'snippet': None,
#   'source': 'The New York Times',
#   'subsection_name': None,
#   'type_of_material': 'Article',
#   'web_url': 'https://query.nytimes.com/gst/abstract.html?res=9903E0D91431E13BBC4950DFB7668389649FDE',
#   'word_count': 30},
#  {'_id': '4fbfd31b45c1498b0d009615',
#   'abstract': None,
#   'blog': [],
#   'byline': None,
#   'document_type': 'article',
#   'headline': {'kicker': '1', 'main': 'Massachusetts Legislature,'},
#   'keywords': [],
#   'lead_paragraph': None,
#   'multimedia': [],
#   'news_desk': None,
#   'print_page': '8',
#   'pub_date': '1852-01-31T00:03:58Z',
#   'section_name': None,
#   'slideshow_credits': None,
#   'snippet': None,
#   'source': 'The New York Times',
#   'subsection_name': None,
#   'type_of_material': 'Article',
#   'web_url': 'https://query.nytimes.com/gst/abstract.html?res=9F00E0D91431E13BBC4950DFB7668389649FDE',
#   'word_count': 35},
#  {'_id': '4fbfd33545c1498b0d009f10',
#   'abstract': 'Missionary labours',
#   'blog': [],
#   'byline': None,
#   'document_type': 'article',
#   'headline': {'main': 'SANDWICH ISLANDS.; Results of Missionary Efforts.'},
#   'keywords': [{'name': 'glocations', 'value': 'SANDWICH ISLANDS'}],
#   'lead_paragraph': 'To the Editor of The New-York Daily Times: An article in '
#                     'your paper of Nov. 11, on the state of the Sandwich '
#                     'Islands, and offering some thoughts regarding annexation, '
#                     'was laid aside for comment, and, for unimportant reasons, '
#                     'has only just been reached.',
#   'multimedia': [],
#   'news_desk': None,
#   'print_page': '7',
#   'pub_date': '1852-01-31T00:03:58Z',
#   'section_name': None,
#   'slideshow_credits': None,
#   'snippet': 'To the Editor of The New-York Daily Times: An article in your '
#              'paper of Nov. 11, on the state of the Sandwich Islands, and '
#              'offering some thoughts regarding annexation, was laid aside for '
#              'comment, and, for unimportant reasons, has only just been rea...',
#   'source': 'The New York Times',
#   'subsection_name': None,
#   'type_of_material': 'Letter',
#   'web_url': 'https://query.nytimes.com/gst/abstract.html?res=9802E1D91431E13BBC4950DFB7668389649FDE',
#   'word_count': 1861},
#  {'_id': '4fbfd31245c1498b0d00928e',
#   'abstract': None,
#   'blog': [],
#   'byline': None,
#   'document_type': 'article',
#   'headline': {'kicker': '1',
#                'main': 'ARRIVAL OF THE CHEROKEE,; $1,090,012 IN GOLD. ARRIVAL '
#                        'OF THE CALIFORNIA MAILS.'},
#   'keywords': [],
#   'lead_paragraph': 'The U. S. mail steamer Cherokee, Capt.. JOHN TANNER, '
#                     'arrived at this port last evening, from Chagres and '
#                     'Kingston. She brings no later California news than that '
#                     'brought by the Prometheus.',
#   'multimedia': [],
#   'news_desk': None,
#   'print_page': '1',
#   'pub_date': '1852-01-31T00:03:58Z',
#   'section_name': None,
#   'slideshow_credits': None,
#   'snippet': 'The U. S. mail steamer Cherokee, Capt.. JOHN TANNER, arrived at '
#              'this port last evening, from Chagres and Kingston. She brings no '
#              'later California news than that brought by the Prometheus....',
#   'source': 'The New York Times',
#   'subsection_name': None,
#   'type_of_material': 'Front Page',
#   'web_url': 'https://query.nytimes.com/gst/abstract.html?res=9D06E2D91431E13BBC4950DFB7668389649FDE',
#   'word_count': 549},
#  {'_id': '4fbfd31b45c1498b0d009616',
#   'abstract': None,
#   'blog': [],
#   'byline': None,
#   'document_type': 'article',
#   'headline': {'kicker': '1', 'main': 'Later from Havana.'},
#   'keywords': [],
#   'lead_paragraph': 'The Prometheus puts us in possession of our Havana files '
#                     'to the 25th inst. The news is of no moment. The Diario '
#                     'contains the official announcement or the vote of thanks '
#                     'from the Spanish Chamber of Deputies to the loyal people '
#                     'of Cuba, for their eminent courage and patriotism in '
#                     'repelling the late piratical invasion.',
#   'multimedia': [],
#   'news_desk': None,
#   'print_page': '1',
#   'pub_date': '1852-01-31T00:03:58Z',
#   'section_name': None,
#   'slideshow_credits': None,
#   'snippet': 'The Prometheus puts us in possession of our Havana files to the '
#              '25th inst. The news is of no moment. The Diario contains the '
#              'official announcement or the vote of thanks from the Spanish '
#              'Chamber of Deputies to the loyal people of Cuba, for their em...',
#   'source': 'The New York Times',
#   'subsection_name': None,
#   'type_of_material': 'Front Page',
#   'web_url': 'https://query.nytimes.com/gst/abstract.html?res=9806E2D91431E13BBC4950DFB7668389649FDE',
#   'word_count': 198},
#  {'_id': '4fbfd31b45c1498b0d00981d',
#   'abstract': 'Trial of Captain',
#   'blog': [],
#   'byline': None,
#   'document_type': 'article',
#   'headline': {'main': 'ARRIVAL OF THE PROMETHEUS.; ARRIVAL OF TIIE '
#                        'PROMETHEUS. $860,000 IN GOLD. SEVENTEEN DAYS LATER. '
#                        'THE PROMETHEUS DIFFICULTY SETTLED, IMPORTANT '
#                        'DISCOVERIES. Important Discovery. The Indian War. '
#                        "Trial of Capt. Waterman. Betrayer of Smith O'Brien. "
#                        'First California Grand Jury. News from the Mines. '
#                        'Miscellaneous. Marriages and Deaths in California. '
#                        'MARRIED. DIED. California Markets.'},
#   'keywords': [{'name': 'subject', 'value': 'CHALLENGE(CLIPPER SHIP)'}],
#   'lead_paragraph': 'The Steamer Prometheus, Capt. H. CHURCHILL, arrived at '
#                     'this port yesterday morning from San Juan, bringing news '
#                     'from San Francisco to the 2d of January, seventeen days '
#                     'later than had been before received. She is consigned to '
#                     'D. B. Allen, and has 355 passengers, $63,000 gold dust on '
#                     'freight, and $800,000 in the hands of passengers.',
#   'multimedia': [],
#   'news_desk': None,
#   'print_page': '1',
#   'pub_date': '1852-01-31T00:03:58Z',
#   'section_name': None,
#   'slideshow_credits': None,
#   'snippet': 'The Steamer Prometheus, Capt. H. CHURCHILL, arrived at this port '
#              'yesterday morning from San Juan, bringing news from San '
#              'Francisco to the 2d of January, seventeen days later than had '
#              'been before received. She is consigned to D. B. Allen, and has '
#              '3...',
#   'source': 'The New York Times',
#   'subsection_name': None,
#   'type_of_material': 'Front Page',
#   'web_url': 'https://query.nytimes.com/gst/abstract.html?res=9E07E2D91431E13BBC4950DFB7668389649FDE',
#   'word_count': 4657}]

# %%
responses = []
# Out:
# 1309
