# %%
# Dependencies
import json
import requests
from pprint import pprint
from API_Keys import API_Key
import pandas as pd
import numpy as np

# baseurl1 = emailed = https://api.nytimes.com/svc/mostpopular/v2/emailed/7.json?api-key=yourkey
# baseurl2 = facebook share = https://api.nytimes.com/svc/mostpopular/v2/shared/1/facebook.json?api-key=yourkey
# baseurl3 = viewed = https://api.nytimes.com/svc/mostpopular/v2/viewed/1.json?api-key=yourkey
# baseurl4 = article search = "https://api.nytimes.com/svc/search/v2/articlesearch.json?"

baseurl1 = "https://api.nytimes.com/svc/mostpopular/v2/emailed/7.json?"
baseurl2 = "https://api.nytimes.com/svc/mostpopular/v2/shared/1/facebook.json?"
baseurl3 = "https://api.nytimes.com/svc/mostpopular/v2/viewed/1.json?"
baseurl4 = "https://api.nytimes.com/svc/search/v2/articlesearch.json?api-key=5GtLqmgGl9W1hvUjnbdmbMFDftGESnsN"

# baseurl4a is baseurl4 with a date range selected = to Jan1 2019 - Sept30 2019
url = "https://api.nytimes.com/svc/search/v2/articlesearch.json?"
begin_date = "20190101"
end_date = "20190930"
query_url4a = f"{url}api-key={api-key}&begin_date={begin_date}&end_date={end_date}"
baseurl4a = query_url4a
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-33d4f8cf7405> in <module>
#      21 begin_date = "20190101"
#      22 end_date = "20190930"
# ---> 23 query_url4a = f"{url}api-key={api-key}&begin_date={begin_date}&end_date={end_date}"
#      24 baseurl4a = query_url4a
#
# NameError: name 'api' is not defined

# %%
# Build query URL
new_url1 = baseurl1 + "api-key=" + api_key
new_url2 = baseurl2 + "api-key=" + api_key
new_url3 = baseurl3 + "api-key=" + api_key
# new_url4 = baseurl4 + "api-key=" + api_key
new_url4 = baseurl4
new_url4a = baseurl4a

print(new_url1)
print(new_url2)
print(new_url3)
print(new_url4)
print(new_url4a)
# Out:
# https://api.nytimes.com/svc/mostpopular/v2/emailed/7.json?api-key=../API_Keys
# https://api.nytimes.com/svc/mostpopular/v2/shared/1/facebook.json?api-key=../API_Keys
# https://api.nytimes.com/svc/mostpopular/v2/viewed/1.json?api-key=../API_Keys
# https://api.nytimes.com/svc/search/v2/articlesearch.json?api-key=5GtLqmgGl9W1hvUjnbdmbMFDftGESnsN
# https://api.nytimes.com/svc/search/v2/articlesearch.json?api-key=pnK1Mz23UG2CNjyghZcMyNDCwAvB4jgX&begin_date=20190101&end_date=20190930

# %%
print(requests.get(new_url1))
print(requests.get(new_url2))
print(requests.get(new_url3))
print(requests.get(new_url4))
print(requests.get(new_url4a)) # for article selection between Jan 1 and Sept 30
# Out:
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>

# %%
# # baseurl1 = emailed = https://api.nytimes.com/svc/mostpopular/v2/emailed/7.json?api-key=yourkey
# # Retrieving data and converting it into JSON
# pprint(requests.get(new_url1).json())

# %%
# # baseurl2 = facebook share = https://api.nytimes.com/svc/mostpopular/v2/shared/1/facebook.json?api-key=yourkey
# pprint(requests.get(new_url2).json())

# %%
# # baseurl3 = viewed = https://api.nytimes.com/svc/mostpopular/v2/viewed/1.json?api-key=yourkey
# pprint(requests.get(new_url3).json())

# %%
# baseurl4 = article search = "https://api.nytimes.com/svc/search/v2/articlesearch.json?"
# displaying JSON data

# pprint(requests.get(new_url4).json())
pprint(requests.get(new_url4a).json())
# Out:
# {'copyright': 'Copyright (c) 2019 The New York Times Company. All Rights '
#               'Reserved.',
#  'response': {'docs': [{'_id': 'nyt://slideshow/e7a72a30-6eab-5264-baf9-61ce53b6dcd5',
#                         'abstract': 'Behind-the-scenes commentary from '
#                                     'producer, Samantha Stark.',
#                         'byline': {'organization': None,
#                                    'original': None,
#                                    'person': []},
#                         'document_type': 'multimedia',
#                         'headline': {'content_kicker': None,
#                                      'kicker': None,
#                                      'main': 'Show notes',
#                                      'name': None,
#                                      'print_headline': None,
#                                      'seo': None,
#                                      'sub': None},
# ...

# %%
# Retrieving data and converting it into JSON

# articles = requests.get(new_url4).json()
articles = requests.get(new_url4a).json()
pprint(articles)
# Out:
# {'copyright': 'Copyright (c) 2019 The New York Times Company. All Rights '
#               'Reserved.',
#  'response': {'docs': [{'_id': 'nyt://slideshow/e7a72a30-6eab-5264-baf9-61ce53b6dcd5',
#                         'abstract': 'Behind-the-scenes commentary from '
#                                     'producer, Samantha Stark.',
#                         'byline': {'organization': None,
#                                    'original': None,
#                                    'person': []},
#                         'document_type': 'multimedia',
#                         'headline': {'content_kicker': None,
#                                      'kicker': None,
#                                      'main': 'Show notes',
#                                      'name': None,
#                                      'print_headline': None,
#                                      'seo': None,
#                                      'sub': None},
# ...

# %%
'''   Attempting to get a count of all articles found in get results
NOTE: NOT SURE WHAT THE NUMBER 1023 BELOW IN THE print(id_counter) IS TELLING ME YET?
NOTE: THE len(id) is equal to 10 which I am assuming is the article limit of 10 being returned.
'''
id = []
id_counter = 0

art_id_dict = articles
for item in art_id_dict["response"]["docs"]:
    id_counter += id_counter + 1
    id.append(item)


print(id_counter)
print(type(id))
# pprint(id)
len(id)

# print(type(art_id_dict))
# pprint(art_id_dict)
# Out:
# 1023
# <class 'list'>
# 10

# %%
'''   Attempting to get a count of all articles found in get results
# Attempting to get ** 5 ** pages of results (10 per page) FOR A TOTAL OF 50
# HINT FROM CLASS NOTE FROM Saturday 9/21 - 6.1 Activities 12-Stu_RetrieveArticles
: Look up the page query param
'''

for x in range(5):
    response2 = requests.get(f"{new_url4a}&page={x}").json()
# pprint(response2)

# id is the joson data at the article ID level and below
id = []
id_counter = 0

art_id_dict = response2
for item in art_id_dict["response"]["docs"]:
    id_counter += id_counter + 1
    id.append(item)

print(id_counter)
print(type(id))
len(id)

# pprint(id)  ## id is the joson data at the article ID level and below
# Out:
# 1023
# <class 'list'>
# 10

# %%
# art0 = response2["response"]["docs"][5]["keywords"][0]["value"]

art1 = response2["response"]["docs"][5]["keywords"]
art2 = art1[0]["value"]

print(type(art1))
pprint(art1)
print()
print(type(art2))
pprint(art2)
print()

KeyWords = []
KeyWords2= []
for key in art1:
#     KeyWords.append(key)
    KeyWords.append(art1[0]["value"])
    for value in KeyWords:
        KeyWords2.append(value)
        


print(type(key))
print(type(KeyWords))
print(type(KeyWords2))

# print(key,KeyWords, KeyWords2)
key, KeyWords, KeyWords2
# Out:
# <class 'list'>
# [{'major': 'N', 'name': 'subject', 'rank': 1, 'value': 'Soccer'},
#  {'major': 'N', 'name': 'glocations', 'rank': 2, 'value': 'Athens (Greece)'},
#  {'major': 'N', 'name': 'subject', 'rank': 3, 'value': 'Philosophy'}]
#
# <class 'str'>
# 'Soccer'
#
# <class 'dict'>
# <class 'list'>
# <class 'list'>
# ({'name': 'subject', 'value': 'Philosophy', 'rank': 3, 'major': 'N'},
#  ['Soccer', 'Soccer', 'Soccer'],
#  ['Soccer', 'Soccer', 'Soccer', 'Soccer', 'Soccer', 'Soccer'])

# %%
print(type(key))
pprint(key)
print()
keytest = key["value"]
print(type(keytest))
'''   Finally getting to the keyword in the value field '''
keytest
# Out:
# <class 'dict'>
# {'major': 'N', 'name': 'subject', 'rank': 3, 'value': 'Philosophy'}
#
# <class 'str'>
# 'Philosophy'

# %%
def get_values():
    for x in range(5):
        response2 = requests.get(f"{new_url4}&page={x}").json()
        art1 = response2["response"]["docs"][5]["keywords"]
        for key in art1:
            keytest = key["value"]
            Saved_Keywords.append(keytest)

# %%
Saved_Keywords = []
# Call Function
get_values()

# %%
Saved_Keywords
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-b7fcf52f7879> in <module>
# ----> 1 Saved_Keywords
#
# NameError: name 'Saved_Keywords' is not defined

# %%
# Put results into a DataFrame
art_df = pd.DataFrame()
art_df["Keywords"]=Saved_Keywords

print("art_df")
print(type(art_df))
art_df
# Out:
# art_df
# <class 'pandas.core.frame.DataFrame'>
#                                           Keywords
# 0                    Murders and Attempted Murders
# 1                       Williamsbridge (Bronx, NY)
# 2                       Education Department (NYC)
# 3   Richard R Green Educational Campus (Bronx, NY)
# 4                                         Assaults
# 5                                             Iraq
# 6                                 Shear, Michael D
# 7                                   Sussman, Dalia
# 8           Islamic State in Iraq and Syria (ISIS)
# 9                                    Obama, Barack
# 10       United States Defense and Military Forces
# 11           United States International Relations
# 12                        Polls and Public Opinion
# 13                                   United States
# 14           United States Politics and Government
# 15                           Gardens and Gardening
# ...
